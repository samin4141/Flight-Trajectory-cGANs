# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("traffic_test_2022.xlsx")

# %%
df.isna().sum()
# Out:
# Unnamed: 0            0
# alert                 0
# altitude         266540
# callsign          31321
# geoaltitude      315945
# groundspeed      263024
# hour                  0
# icao24                0
# last_position         0
# latitude              0
# longitude             0
# onground              0
# spi                   0
# squawk           189076
# timestamp             0
# track            263024
# vertical_rate    263024
# dtype: int64

# %%
list(df["icao24"].unique())
# Out:
# ['a437c0',
#  'c02eb9',
#  'c0583a',
#  'c05edf',
#  'c07c7a',
#  'c06709',
#  'c06080',
#  'c05bd2',
#  'c030fd',
#  'c030ef',
#  'c010ec',
#  'c05ed9',
#  'c01e28',
#  'c010e4',
#  'c010cb',
#  'c05ea2',
#  'c05bd5',
#  'c07966',
#  'c07b05',
#  'c06081',
#  'c06539',
#  'c0219c',
#  'c0797b',
#  'c01040',
#  'c0192e',
#  'c027d1',
#  'c0582b',
#  'c04fd7',
#  'c023c7',
#  'c01c52',
#  'c058c2',
#  'c01755',
#  'c010a8',
#  'c04fe4',
#  'c07c7b',
#  '800c3e',
#  'a1efe7',
#  'ac2c23',
#  'c0468e',
#  'a57231',
#  'a4bf49',
#  40740000,
#  'c06c1f',
#  'c1e7db',
#  'c1e815',
#  'c1e845',
#  'c1e847',
#  780504,
#  'c00020',
#  'ac7d68',
#  'c00380',
#  'c00c67',
#  'c00f36',
#  'c01442',
#  'c02708',
#  'c027b9',
#  'c033aa',
#  'c040a5',
#  'c044bd',
#  'c047e7',
#  'c04d9b',
#  'c04e31',
#  'c04ed0',
#  'c04f83',
#  'c053e3',
#  'c054a3',
#  'c062a2',
#  'c06489',
#  'c065d4',
#  'c0682d',
#  'c06b3e',
#  'c073b3',
#  'c074b1',
#  'c0774c',
#  'c07f8a',
#  'c08566',
#  'c08569',
# ...
